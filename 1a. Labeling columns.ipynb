# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv(r'C:\Users\User\Desktop\tugas akhir files\cstudent_grade.csv')
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   Dalc Walc  health  absences  G1  G2  G3   AvgGrade grades PorF
# 0    1    1       3         6   5   6   6   5.666667      F    F
# 1    1    1       3         4   5   5   6   5.333333      F    F
# 2    2    3       3        10   7   8  10   8.333333      F    F
# 3    1    1       5         2  15  14  15  14.666667      C    P
# 4    1    2       5         4   6  10  10   8.666667      F    F
#
# [5 rows x 36 columns]

# %%
# Label all string column into integer values
# for yes / no values:
d = {'no': 0, 'yes': 1}
df['schoolsup'] = df['schoolsup'].map(d)
df['famsup'] = df['famsup'].map(d)
df['paid'] = df['paid'].map(d)
df['activities'] = df['activities'].map(d)
df['nursery'] = df['nursery'].map(d)
df['higher'] = df['higher'].map(d)
df['internet'] = df['internet'].map(d)
df['romantic'] = df['romantic'].map(d)

# map the sex df
d = {'F': 1, 'M': 0}
df['sex'] = df['sex'].map(d)
# map the address df
d = {'U': 1, 'R': 0}
df['address'] = df['address'].map(d)
# map the family size size df
d = {'LE3': 1, 'GT3': 0}
df['famsize'] = df['famsize'].map(d)
# map the parent's status
d = {'T': 1, 'A': 0}
df['Pstatus'] = df['Pstatus'].map(d)
# map the parent's # # Data correlation
plt.figure(figsize=(20,10))
sns.heatmap(df_corr.corr(method='spearman'),annot=True,cmap='CMRmap_r',fmt='.3f',linewidths=2)
plt.show()
d = {'teacher': 0, 'health': 1, 'services': 2,'at_home': 3,'other': 4}
df['Mjob'] = df['Mjob'].map(d)
df['Fjob'] = df['Fjob'].map(d)
# map the reason df
d = {'home': 0, 'reputation': 1, 'course': 2,'other': 3}
df['reason'] = df['reason'].map(d)
# map the guardian df
d = {'mother': 0, 'father': 1, 'other': 2}
df['guardian'] = df['guardian'].map(d)
# map the grades df
d = {'F': 0, 'D': 1, 'C': 2, 'B': 3 , 'A': 4}
df['grades'] = df['grades'].map(d)
# map Pass or Fail df
d = {'F': 0, 'P': 1}
df['PorF'] = df['PorF'].map(d)# # Data correlation
plt.figure(figsize=(20,10))
sns.heatmap(df_corr.corr(method='spearman'),annot=True,cmap='CMRmap_r',fmt='.3f',linewidths=2)
plt.show()

# %%
df.head()

# %%
#save as new dataset for Machine Learning
# df.to_csv('student_grade.csv', index = None, header=True)

# %%
# Corelate all features with the target 'grades'
df_corr= df.drop(['PorF','AvgGrade','G3','G2','G1'], axis='columns')
corr_matrix = df_corr.corr(method='spearman')
corr_matrix['grades'].sort_values(ascending=False)
